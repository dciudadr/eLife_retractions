# %%
import os
import pandas as pd

ds_name2 = 'df_retracted_retraction_400_450.tsv'

data_path = 'data'
analysis_path = os.path.join(data_path, 'analysis')



df_articles_citing_retracted_paper2 = pd.read_csv(ds_name2, sep='\t', encoding='utf-8')


df_articles_citing_retracted_paper2
# Out:
#                              DOI_cited  \
# 0                    10.1104/pp.011019
# 1                    10.1104/pp.011019
# 2              10.1073/pnas.0501997102
# 3              10.1073/pnas.0501997102
# 4                        10.1038/77997
# 5   10.1213/01.ane.0000221167.58135.3d
# 6   10.1213/01.ane.0000221167.58135.3d
# 7   10.1213/01.ane.0000221167.58135.3d
# 8   10.1213/01.ane.0000221167.58135.3d
# 9   10.1213/01.ane.0000221167.58135.3d
# 10                    10.1038/35044106
# 11           10.4049/jimmunol.170.1.64
# 12               10.1055/s-2006-924577
# 13               10.1055/s-2006-924577
# 14               10.1055/s-2006-924577
# 15          10.1016/j.cell.2008.01.051
# 16          10.1016/j.cell.2008.01.051
# 17    10.1111/j.1365-2958.2005.04612.x
# 18           10.1016/j.str.2008.04.010
# 19           10.1016/j.str.2008.04.010
# 20                   10.1002/ajh.20284
# 21                    10.1038/35102506
# 22                    10.1038/35102506
# 23                   10.1021/bi050786j
# 24               10.1104/pp.103.037770
# 25             10.1126/science.1107733
# 26             10.1126/science.1119776
# 27                10.1084/jem.20020881
# 28                10.1084/jem.20020881
#
#                                        article_citing
# 0   <html>\n <body>\n  <article article-type="rese...
# 1   <html>\n <body>\n  <p>\n   BMC_Complement_Alte...
# 2   <html>\n <body>\n  <article-title>\n   S1P3 re...
# 3   \n     <floats-group>\n      <fig id="ijms-18-...
# 4   <html>\n <body>\n  <article article-type="rese...
# 5   <html>\n <body>\n  <p>\n   (PDF 92 KB)\n  </p>...
# 6   \n <p>\n  BMC_Anesthesiol/PMC4240803.nxml     ...
# 7   \n <floats-group>\n  <fig id="fig1" orientatio...
# 8   <html>\n <body>\n  <p>\n   Crit_Care/PMC367272...
# 9   \n  Crit_Care/PMC4256754.nxml                 ...
# 10  <html>\n <body>\n  <italic>\n   In vivo\n  </i...
# 11  <html>\n <body>\n  <article-title>\n   Charact...
# 12  <html>\n <body>\n  <article article-type="rese...
# 13  <html>\n <body>\n  <p>\n   Int_J_Health_Geogr/...
# 14  <html>\n <body>\n  <p>\n   J_Occup_Med_Toxicol...
# 15  <html>\n <body>\n  <article article-type="revi...
# 16  <html>\n <body>\n  <ref id="R114">\n   <label>...
# 17  <html>\n <body>\n  <article-title>\n   luxS in...
# 18  <html>\n <body>\n  <inline-formula>\n   <mml:m...
# 19  \n <p>\n  BMC_Struct_Biol/PMC2998507.nxml     ...
# 20  <html>\n <body>\n  <article article-type="rese...
# 21  <html>\n <body>\n  <article article-type="revi...
# 22  <html>\n <body>\n  <p>\n   BMC_Neurosci/PMC445...
# 23  <html>\n <body>\n  <year>\n   2005\n  </year>\...
# 24  <html>\n <body>\n  <p>\n   MathType@MTEF@5@5@+...
# 25  <html>\n <body>\n  <article-title>\n   Structu...
# 26  <html>\n <body>\n  <article article-type="rese...
# 27  <html>\n <body>\n  <article article-type="rese...
# 28  <html>\n <body>\n  <article article-type="retr...

# %%
'df_retracted_retraction_0_100.tsv' - 66 articles citing
'df_retracted_retraction_100_200.tsv' - 92
'df_retracted_retraction_200_300.tsv' - 84
'df_retracted_retraction_300_400.tsv' - 127
'df_retracted_retraction_400_450.tsv' - 28
