# %%
import os
import pandas as pd

ds_name2 = 'df_retracted_retraction_0_100.tsv'

data_path = 'data'
analysis_path = os.path.join(data_path, 'analysis')



df_articles_citing_retracted_paper2 = pd.read_csv(ds_name2, sep='\t', encoding='utf-8')


df_articles_citing_retracted_paper2
# Out:
#                               DOI_cited  \
# 0                10.1136/ip.2006.015115
# 1                10.1136/ip.2006.015115
# 2             10.1186/s40478-016-0393-5
# 3   10.1016/j.freeradbiomed.2011.11.027
# 4              10.1128/genomeA.00731-17
# 5         10.1126/science.346.6216.1486
# 6                 10.3892/mmr.2017.7084
# 7             10.1186/s13033-017-0143-5
# 8             10.1186/s13033-017-0143-5
# 9                     10.7150/jca.15753
# 10               10.1038/sdata.2016.120
# 11                   10.1038/ncomms6446
# 12                   10.1038/ncomms6446
# 13                   10.1093/nar/gks812
# 14                10.3892/mmr.2016.5294
# 15                   10.1002/cbin.10615
# 16                   10.1002/cbin.10291
# 17                   10.1002/cbin.10291
# 18         10.1371/journal.pone.0164378
# 19                 10.1021/jacs.6b01652
# 20         10.1371/journal.pone.0164571
# 21         10.1371/journal.pone.0164571
# ...

# %%
'df_retracted_retraction_0_100.tsv' - 66 articles citing
'df_retracted_retraction_100_200.tsv' - 92
'df_retracted_retraction_200_300.tsv' - 84
'df_retracted_retraction_300_400.tsv' - 127
'df_retracted_retraction_400_450.tsv' - 28

# %%
66 + 92 + 84 + 127 + 28
# Out:
# 397
